# %% [markdown]
# CAREER POINT KENYA

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.careerpointkenya.co.ke/'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup.title.string
# Out:
# 'Latest 137 Jobs Vacancies In Kenya - Career Point Kenya'

# %%
url2 = 'https://www.careerpointkenya.co.ke/top-common-interview-questions-and-answers-in-kenya/'

# %%
response2 = requests.get(url2)

# %%
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.text,'html.parser')

# %%
soup2.title.string
# Out:
# 'Common Interview Questions and Answers - Career Point Kenya'

# %%
url3='https://www.careerpointkenya.co.ke/short-courses-in-kenya-best/'

# %%
response3 = requests.get(url3)

# %%
response3.status_code
# Out:
# 200

# %%
soup3 = BeautifulSoup(response3.text,'html.parser')

# %%
soup3.title.string
# Out:
# 'Short Courses In Kenya You Should Pursue To Get A Job Fast | Career Point Kenya'

# %%
soup.find('a')
# Out:
# <a class="skip-link screen-reader-text scroll-ignore" href="#main">Skip to content</a>

# %%
soup.find_all('li',class_='menu-item')
# Out:
# [<li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-1188 current_page_item menu-item-779105" id="menu-item-779105"><a aria-current="page" href="https://www.careerpointkenya.co.ke/">Home</a></li>,
#  <li class="menu-item menu-item-type-post_type_archive menu-item-object-job menu-item-779040" id="menu-item-779040"><a href="https://www.careerpointkenya.co.ke/jobs/">Latest Jobs</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-562955" id="menu-item-562955"><a href="https://www.careerpointkenya.co.ke/cv-writing-services-kenya/">CV Writing</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-586395" id="menu-item-586395"><a href="https://www.careerpointkenya.co.ke/recruitment-agencies-kenya/">Recruitment Firms</a></li>,
# ...

# %%
soup.find_all('li',class_ = 'menu-item')
# Out:
# [<li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-1188 current_page_item menu-item-779105" id="menu-item-779105"><a aria-current="page" href="https://www.careerpointkenya.co.ke/">Home</a></li>,
#  <li class="menu-item menu-item-type-post_type_archive menu-item-object-job menu-item-779040" id="menu-item-779040"><a href="https://www.careerpointkenya.co.ke/jobs/">Latest Jobs</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-562955" id="menu-item-562955"><a href="https://www.careerpointkenya.co.ke/cv-writing-services-kenya/">CV Writing</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-586395" id="menu-item-586395"><a href="https://www.careerpointkenya.co.ke/recruitment-agencies-kenya/">Recruitment Firms</a></li>,
# ...

# %%
tags= soup.find_all('li',class_ ='menu-item')

# %%
names= []
for i in tags:
  a_tag = i.find('a')
  if a_tag:
    names.append(a_tag)
  else:
    print(f'no a tag : {i}')

# %%
for name in names:
  print(name.text,name['href'])
# Out:
# Home https://www.careerpointkenya.co.ke/
# Latest Jobs https://www.careerpointkenya.co.ke/jobs/
# CV Writing https://www.careerpointkenya.co.ke/cv-writing-services-kenya/
# Recruitment Firms https://www.careerpointkenya.co.ke/recruitment-agencies-kenya/
# Best Interview Answers https://www.careerpointkenya.co.ke/top-common-interview-questions-and-answers-in-kenya/
# New Short Courses https://www.careerpointkenya.co.ke/short-courses-in-kenya-best/
# Free Job Posting https://www.careerpointkenya.co.ke/free-job-advertising/
# New Jobs https://www.careerpointkenya.co.ke/jobs/
# CV Writing https://www.careerpointkenya.co.ke/cv-writing-services-kenya/
# Interview Q&A https://www.careerpointkenya.co.ke/top-common-interview-questions-and-answers-in-kenya/
# Short Courses https://www.careerpointkenya.co.ke/short-courses-in-kenya-best/
# Free Job Advertising https://www.careerpointkenya.co.ke/free-job-advertising/
# ...

# %%
print(names)
# Out:
# [<a aria-current="page" href="https://www.careerpointkenya.co.ke/">Home</a>, <a href="https://www.careerpointkenya.co.ke/jobs/">Latest Jobs</a>, <a href="https://www.careerpointkenya.co.ke/cv-writing-services-kenya/">CV Writing</a>, <a href="https://www.careerpointkenya.co.ke/recruitment-agencies-kenya/">Recruitment Firms</a>, <a href="https://www.careerpointkenya.co.ke/top-common-interview-questions-and-answers-in-kenya/">Best Interview Answers</a>, <a href="https://www.careerpointkenya.co.ke/short-courses-in-kenya-best/">New Short Courses</a>, <a href="https://www.careerpointkenya.co.ke/free-job-advertising/">Free Job Posting</a>, <a href="https://www.careerpointkenya.co.ke/jobs/">New Jobs</a>, <a href="https://www.careerpointkenya.co.ke/cv-writing-services-kenya/">CV Writing</a>, <a href="https://www.careerpointkenya.co.ke/top-common-interview-questions-and-answers-in-kenya/">Interview Q&amp;A</a>, <a href="https://www.careerpointkenya.co.ke/short-courses-in-kenya-best/">Short Cou
# ...

# %%
len(tags)
# Out:
# 21

# %%
soup.find_all('div',class_='kt-inside-inner-col')
# Out:
# [<div class="kt-inside-inner-col"><h1 class="kt-adv-heading778117_a0c96d-c3 wp-block-kadence-advancedheading has-theme-palette-9-color has-text-color" data-kb-block="kb-adv-heading778117_a0c96d-c3">Latest Jobs in Kenya &amp; Career Advice for You</h1><p class="kt-adv-heading778117_664184-00 wp-block-kadence-advancedheading has-theme-palette-9-color has-text-color" data-kb-block="kb-adv-heading778117_664184-00">Career Point Kenya is a leading job site where we post latest job vacancies in Kenya. Are you looking for your next job? Register today for free job alerts. Looking to hire the best? Its FREE. Post your Kenyan job &amp; reach over 500,000 qualified professionals in Kenya.</p></div>,
# ...

# %%
tags2= soup.find_all('div',class_='kt-inside-inner-col')

# %%
len(tags2)
# Out:
# 81

# %%
h3_tag = soup.find_all('h3')

# %%
for h3 in h3_tag:
  print(h3.text)
# Out:
# Accounting
# Administration
# Banking
# Customer Service
# Driver
# Engineering
# HR
# Internships
# IT
# Legal
# Jobs in Nairobi
# Jobs in Mombasa
# Jobs in Kisumu
# Jobs in Nyeri
# Jobs in Nakuru
# Jobs in Eldoret
# Jobs in Thika

# %%
for tag in tags2:
  a_tags = tag.find('a')
  if a_tags:
    print(a_tags['href'])
# Out:
# https://www.careerpointkenya.co.ke/jobs/
# https://www.careerpointkenya.co.ke/jobs/
# https://www.careerpointkenya.co.ke/jobs/
# https://www.careerpointkenya.co.ke/category/accounting-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/accounting-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/administration-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/banking-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/customer-service-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/driver-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/engineering-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/hr-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/internships-in-kenya/
# https://www.careerpointkenya.co.ke/category/it-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/category/legal-jobs-in-kenya/
# https://www.careerpointkenya.co.ke/jobs/
# https://www.careerpointkenya.co.ke/job-type/full-time/
# ...

# %%
print(h3.text,a_tags['href'])
# Out:
# Jobs in Thika https://www.careerpointkenya.co.ke/free-job-advertising/

# %%
urls = []
for tag in tags2:
  h3_tag = tags2.find_all('h3')
  urls.append(h3_tag.attrs['href'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-6607c7e96d82> in <cell line: 2>()
#       1 urls = []
#       2 for tag in tags2:
# ----> 3   h3_tag = tags2.find_all('h3')
#       4   urls.append(h3_tag.attrs['href'])
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
names= [2]
for jobs in tags2:
  h3_tag = jobs.find('h3')
  if h3_tag:
    names.append(h3_tag)
  else:
    print(f'no h3 tag : {i}')

# %%
h3_tag = tags2.find('h3')

# %%
jobs= tags2.find_all('h3')
for job in jobs:
  print(job.text)
