# %% [markdown]
# ## NASA API

# %%
# !pip install requests
import requests
import json
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### CME DATA

# %%
## https://api.nasa.gov/DONKI/CMEiONih6Ohd64XGSWHh3P8RbZSZ94pdRZ8gaVLb65d

# %%
api_key = "iONih6Ohd64XGSWHh3P8RbZSZ94pdRZ8gaVLb65d"

# %%
cme_base_url = 'https://api.nasa.gov/DONKI/CME'

# %%
cme_url = f'{cme_base_url}?startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key={api_key}'

# %%
response = requests.get(cme_url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'activityID': '2016-09-02T06:18:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2016-09-02T06:18Z',
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/11209/-1',
#   'note': 'Start time is time when seen in SOHO LASCO C3 due to a data gap in SOHO LASCO C2 imagery.',
#   'submissionTime': '2016-09-02T14:42Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2016-09-02T19:15Z',
#     'latitude': 35.0,
#     'longitude': -87.0,
#     'halfAngle': 27.0,
#     'speed': 218.0,
#     'type': 'S',
#     'featureCode': 'null',
#     'imageType': None,
#     'measurementTechnique': 'null',
#     'note': '',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
# ...

# %%
## https://api.nasa.gov/DONKI/CMEAnalysis?startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key=DEMO_KEY

# %%
startDate = '2016-12-01'
endDate = '2016-12-30'
cme_base_url = 'https://api.nasa.gov/DONKI/CME'

# %%
cme_url_2= f'{cme_base_url}?startDate={startDate}&endDate={endDate}&api_key={api_key}'

# %%
response = requests.get(cme_url_2)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'activityID': '2016-12-02T22:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2016-12-02T22:12Z',
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/11749/-1',
#   'note': 'The source is unclear but could be a central disk eruption visible in SDO 193 around 16:13.',
#   'submissionTime': '2016-12-03T14:05Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2016-12-03T12:22Z',
#     'latitude': -20.0,
#     'longitude': 49.0,
#     'halfAngle': 18.0,
#     'speed': 328.0,
#     'type': 'S',
#     'featureCode': 'null',
#     'imageType': None,
#     'measurementTechnique': 'null',
#     'note': '',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2016-12-03T14:06Z',
# ...

# %% [markdown]
# #### IPS DATA

# %%
# https://api.nasa.gov/DONKI/IPS?startDate=yyyy-MM-dd&endDate=yyyy-MM-dd&location=LOCATION&catalog=CATALOG&api_key=DEMO_KEY

# %%
ips_base_url = "https://api.nasa.gov/DONKI/IPS"

# %%
startDate='2016-04-01'
endDate = '2016-04-30'

# %%
ips_url = f'{ips_base_url}?startDate={startDate}&endDate={endDate}&api_key={api_key}'

# %%
response = requests.get(ips_url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'catalog': 'M2M_CATALOG',
#   'activityID': '2016-04-02T14:04:00-IPS-001',
#   'location': 'Earth',
#   'eventTime': '2016-04-02T14:04Z',
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/10418/-1',
#   'instruments': [{'displayName': 'ACE: MAG'}, {'displayName': 'ACE: SWEPAM'}],
#   'submissionTime': '2016-04-02T16:16Z'},
#  {'catalog': 'M2M_CATALOG',
#   'activityID': '2016-04-10T09:00:00-IPS-001',
#   'location': 'Earth',
#   'eventTime': '2016-04-10T09:00Z',
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/10473/-1',
#   'instruments': [{'displayName': 'ACE: MAG'}, {'displayName': 'ACE: SWEPAM'}],
#   'submissionTime': '2016-04-10T18:07Z'},
#  {'catalog': 'M2M_CATALOG',
#   'activityID': '2016-04-14T06:50:00-IPS-001',
#   'location': 'Earth',
#   'eventTime': '2016-04-14T06:50Z',
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/10491/-1',
#   'instruments': [{'displayName': 'ACE: MAG'}, {'displayName': 'ACE: SWEPAM'}],
# ...
